# %% [markdown]
# <a href="https://colab.research.google.com/github/kiminhee0311/-/blob/master/Untitled0_191204.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
print('hello world!')
# Out:
# hello world!

# %%
# !pip install --upgrade tensorflow
# Out:
# ...
#      |████████████████████████████████| 86.3MB 41kB/s
# ...
#      |████████████████████████████████| 3.8MB 32.6MB/s
# ...
#      |████████████████████████████████| 450kB 44.9MB/s
# ...
#      |████████████████████████████████| 81kB 8.3MB/s
# ...
# ERROR: tensorboard 2.0.2 has requirement grpcio>=1.24.3, but you'll have grpcio 1.15.0 which is incompatible.
# ERROR: google-colab 1.0.0 has requirement google-auth~=1.4.0, but you'll have google-auth 1.7.1 which is incompatible.
# ...
#   Found existing installation: google-auth 1.4.2
#     Uninstalling google-auth-1.4.2:
#       Successfully uninstalled google-auth-1.4.2
#   Found existing installation: tensorboard 1.15.0
#     Uninstalling tensorboard-1.15.0:
#       Successfully uninstalled tensorboard-1.15.0
#   Found existing installation: tensorflow-estimator 1.15.1
#     Uninstalling tensorflow-estimator-1.15.1:
#       Successfully uninstalled tensorflow-estimator-1.15.1
#   Found existing installation: tensorflow 1.15.0
#     Uninstalling tensorflow-1.15.0:
# ...

# %%
import tensorflow as tf
tf.__version__
# 버전 확인
# Out:
# '2.0.0'

# %%
import tensorflow as tf
from tensorflow import keras
import numpy as np
import matplotlib.pyplot as plt

# %%
np.random.seed(0)
tf.random.set_seed(0)
#설정

# %%
mnist = keras.datasets.mnist
(x_train, y_train), (x_test, y_test) = mnist.load_data()
#테스트용 데이터와 학습용 데이터 로드
# Out:
# ...
# 11493376/11490434 [==============================] - 0s 0us/step

# %%
x_train = x_train/255
x_test = x_test/255

# %%
y_train = keras.backend.one_hot(y_train, 10)
y_test = keras.backend.one_hot(y_test, 10)
# Out:
# ---------------------------------------------------------------------------
# NotFoundError                             Traceback (most recent call last)
# <ipython-input-10-04e8a1ee254f> in <module>()
# ----> 1 y_train = keras.backend.one_hot(y_train, 10)
#       2 y_test = keras.backend.one_hot(y_test, 10)
#
# /usr/local/lib/python3.6/dist-packages/tensorflow_core/python/keras/backend.py in one_hot(indices, num_classes)
#    3229       The one-hot tensor.
#    3230   """
# -> 3231   return array_ops.one_hot(indices, depth=num_classes, axis=-1)
#    3232
#    3233
#
# /usr/local/lib/python3.6/dist-packages/tensorflow_core/python/ops/array_ops.py in one_hot(indices, depth, on_value, off_value, axis, dtype, name)
#    3512
#    3513     return gen_array_ops.one_hot(indices, depth, on_value, off_value, axis,
# -> 3514                                  name)
#    3515
#    3516
#
# ...

# %%
model = keras.models.Sequential([
    keras.layers.Flatten(input_shape = (28,28)),
    keras.layers.Dense(256, activation = 'relu'),
    keras.layers.Dense(128, activation = 'relu'),
    keras.layers.Dense(64, activation = 'relu'),
    keras.layers.Dense(10, activation = 'softmax')
])

# %%
model.compile(optimizer = 'adam', loss = 'categorical_crossentropy',
              metrics = ['accuracy'])

# %%
model.fit(x_train, y_train, epochs = 5)
# Out:
# Train on 60000 samples
# Epoch 1/5
# 60000/60000 [==============================] - 8s 132us/sample - loss: 0.0880 - accuracy: 0.9733
# Epoch 2/5
# 60000/60000 [==============================] - 8s 140us/sample - loss: 0.0653 - accuracy: 0.9796
# Epoch 3/5
# 60000/60000 [==============================] - 9s 144us/sample - loss: 0.0488 - accuracy: 0.9842
# Epoch 4/5
# 60000/60000 [==============================] - 9s 142us/sample - loss: 0.0389 - accuracy: 0.9878
# Epoch 5/5
# 60000/60000 [==============================] - 7s 123us/sample - loss: 0.0337 - accuracy: 0.9893

# %%
model.evaluate(x_test, y_test)
# Out:
# 10000/1 [=============================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================
# ...
